# %% [markdown]
#  <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
#  **Ekta Shah**
#
# Data Scientist

# %% [markdown]
# *I am intrested in Data Science because of the vast areas it can be pluged into and discovering insites to the solutions of the problem.*

# %% [markdown]
# ### The below code is used to add two numbers using variables and assigning to the third vairable that is used to store the result

# %%
a = 1
b = 2
c = a+b
print('Sum = '+str(c))
# Out:
# Sum = 3

# %% [markdown]
# Example for markdown hyperlink - [IBM Website][1]
#
# [1]: https://www.ibm.com/in-en "Title"
#
#
# ### Bullet List
#
# * Bullet 1
# * Bullet 2
# * Bullet 2
#
# ### Number list with sublist and sub-sub list
#
# 1. number list 1
# 2. number list 2
#     * sublist 1
#         * sub-sublist 1
